# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/customembeddingtraining/Final Training Clean DL.csv

# %%
df = pd.read_csv('/kaggle/input/customembeddingtraining/Final Training Clean DL.csv')
df.head()
# Out:
#                         Consumer complaint narrative  \
# 0  transworld systems inc. \nis trying to collect...
# 1  I would like to request the suppression of the...
# 2  Over the past 2 weeks, I have been receiving e...
# 3  I was sold access to an event digitally, of wh...
# 4  While checking my credit report I noticed thre...
#
#                                     Total Clean Text
# 0  trans world systems inc be try to collect  deb...
# 1   would like to request the suppression of the ...
# 2  over the past  weeks  have be receive excessiv...
# 3   be sell access to an event digitally of which...
# 4  while check my credit report  notice three col...

# %%
df.shape
# Out:
# (506162, 2)

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from tqdm import tqdm
tqdm.pandas()

# %%
stop_words = list(set(stopwords.words('english')))+['unknown','xx','xxx','xxxx']

# %%
def cleaning(text):
    text = text.lower()
    words = word_tokenize(text)
    words = [w for w in words if w not in stop_words]
    return ' '.join(words)

df['After Stop Word Removal'] = df['Total Clean Text'].progress_apply(cleaning)
# Out:
# 100%|██████████| 506162/506162 [18:32<00:00, 455.08it/s]

# %%
df.to_csv('Consumer Complaint After Cleaning and Stop Words Removed.csv',index = False)

# %%
df.head()
# Out:
#                         Consumer complaint narrative  \
# 0  transworld systems inc. \nis trying to collect...
# 1  I would like to request the suppression of the...
# 2  Over the past 2 weeks, I have been receiving e...
# 3  I was sold access to an event digitally, of wh...
# 4  While checking my credit report I noticed thre...
#
#                                     Total Clean Text  \
# 0  trans world systems inc be try to collect  deb...
# 1   would like to request the suppression of the ...
# 2  over the past  weeks  have be receive excessiv...
# 3   be sell access to an event digitally of which...
# 4  while check my credit report  notice three col...
#
#                              After Stop Word Removal
# 0  trans world systems inc try collect debt mine ...
# 1  would like request suppression follow items cr...
# 2  past weeks receive excessive amount telephone ...
# 3  sell access event digitally screenshots detail...
# 4  check credit report notice three collections c...

# %%
text = df['After Stop Word Removal'].values
text = ' '.join(text)

# %%
type(text)
# Out:
# str

# %%
import re
from itertools import islice
from collections import Counter
words = re.findall("\w+", text)
#print (Counter(zip(words, islice(words, 1, None))))
x = (Counter(zip(words, islice(words, 1, None))))
D = dict(x)

# %%
import operator
sorted_x = sorted(D.items(), key=operator.itemgetter(1),reverse = True)

# %%
top_50 = dict(sorted_x[:50])
top_50
# Out:
# {('credit', 'report'): 286509,
#  ('credit', 'card'): 104561,
#  ('qui', 'fax'): 75355,
#  ('ex', 'peri'): 54591,
#  ('well', 'fargo'): 53949,
#  ('credit', 'bureaus'): 50546,
#  ('identity', 'theft'): 46972,
#  ('trans', 'union'): 45732,
#  ('credit', 'score'): 43663,
#  ('customer', 'service'): 43305,
#  ('fc', 'ra'): 40246,
#  ('report', 'credit'): 37848,
#  ('bank', 'america'): 37065,
#  ('phone', 'call'): 35687,
#  ('call', 'back'): 34711,
#  ('check', 'account'): 33364,
#  ('student', 'loan'): 33103,
#  ('30', 'days'): 33018,
#  ('navi', 'ent'): 31612,
#  ('collection', 'agency'): 30294,
#  ('would', 'like'): 29862,
#  ('receive', 'letter'): 29462,
#  ('credit', 'file'): 29284,
#  ('make', 'payment'): 29145,
#  ('capital', 'one'): 28296,
#  ('make', 'payments'): 27740,
#  ('close', 'account'): 27611,
#  ('never', 'receive'): 27268,
#  ('send', 'letter'): 27259,
#  ('account', 'number'): 27200,
#  ('report', 'agency'): 26822,
#  ('remove', 'credit'): 26803,
#  ('late', 'fee'): 26792,
#  ('even', 'though'): 26166,
#  ('past', 'due'): 25695,
#  ('consumer', 'report'): 25379,
#  ('phone', 'number'): 24500,
#  ('citi', 'bank'): 24368,
#  ('credit', 'bureau'): 24339,
#  ('social', 'security'): 24190,
#  ('pay', 'full'): 23863,
#  ('bank', 'account'): 23852,
#  ('account', 'credit'): 22743,
#  ('fair', 'credit'): 21242,
#  ('oc', 'wen'): 20938,
#  ('debt', 'collection'): 20937,
#  ('several', 'time'): 20830,
#  ('tell', 'would'): 20647,
#  ('open', 'account'): 20231,
#  ('information', 'credit'): 20087}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize= (20,12))
plt.bar(range(len(top_50)), list(top_50.values()), align='center')
plt.xticks(range(len(top_50)), list(top_50.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
#plt.figure(figsize= (20,12))
plt.xticks(rotation=90)
plt.show()

# %%
import re
from itertools import islice
from collections import Counter
words = re.findall("\w+", text)
from itertools import tee, islice

def ngrams(lst, n):
    
  tlst = lst
  while True:
    a, b = tee(tlst)
    l = tuple(islice(a, n))
    if len(l) == n:
      yield l
      next(b)
      tlst = b
    else:
      break
    

trigram = Counter(ngrams(words, 3))
#x = (Counter(zip(words, islice(words, 1, None))))
#D = dict(x)

# %%
trigram_dict = dict(trigram)

sorted_trigram = sorted(trigram_dict.items(), key=operator.itemgetter(1),reverse = True)

# %%
top_50_trigram = dict(sorted_trigram[:50])
top_50_trigram

# %%
plt.figure(figsize= (20,12))
plt.bar(range(len(top_50_trigram)), list(top_50_trigram.values()), align='center')
plt.xticks(range(len(top_50_trigram)), list(top_50_trigram.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
#plt.figure(figsize= (20,12))
plt.xticks(rotation=90)
plt.show()
